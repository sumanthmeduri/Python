# %%
# %matplotlib inline
#import matplotlib
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[2,5,7])
plt.title("Sumanth's Data")
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.show()

# %%
x=([1,5,4])
y=([22,37,54])

x1=([2,4,4])
y1=([11,33,19])

plt.plot(x,y, label='First', linewidth=4)
plt.plot(x1,y1, label='Second')
plt.legend()
plt.show()

# %%
plt.scatter(x,y)
plt.scatter(x1,y1)
